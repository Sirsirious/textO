# %%
import pandas as pd
import numpy as np
import nltk
from queue import *

nodes = pd.read_csv('data/Networks/MilkO/nodes.csv')
edges = pd.read_csv('data/Networks/MilkO/edges.csv')

# %%
import pixiedust
# Out:
# Pixiedust database opened successfully
#         <div style="margin:10px">
#             <a href="https://github.com/ibm-watson-data-lab/pixiedust" target="_new">
#                 <img src="https://github.com/ibm-watson-data-lab/pixiedust/raw/master/docs/_static/pd_icon32.png" style="float:left;margin-right:10px"/>
#             </a>
#             <span>Pixiedust version 1.1.15</span>
#         </div>

# %%
dictionary = set()
for index, node in nodes.iterrows():
    dictionary.add(node['Label'])

# %%
graph = {}
for index, edge in edges.iterrows():
    graph[edge['main']]=[{0}]
    for i in range(1, len(edges.columns)):
        if(isinstance(edge[i], float)):
            break;
        else:
            graph[edge['main']].append({'term':edge[i],'weight':0})

# %%
def processSent(textEntry, graph):
    tokenized = map(str.lower, textEntry.split())
    traversedList = set()
    i = 1
    for word in tokenized:
        if word in dictionary:
            graph[word][0]=1
            graph, traversedList = spread(word, graph, traversedList, previousScore=1)
            i=i+1
    return graph

def spread(word, graph, traversedList, previousScore=1, weigth=1, decay=0.1,treshold=0.2):
    futureTraversals = Queue()
    if (previousScore > treshold):
        for i in range(1, len(graph[word])-1):
            if graph[word][i].get('weight')==0:
                graph[word][i].update({'weight':previousScore})
            graph[word][i].update({'weight':graph[word][i].get('weight')-(weigth*decay)})
            if graph[word][i]['term'] not in traversedList:
                futureTraversals.put({'term':graph[word][i].get('term'), 'weight':graph[word][i].get('weight')})
                traversedList.add(graph[word][i].get('term'))
        if(not futureTraversals.empty()):
            while not futureTraversals.empty():
                totraverse = futureTraversals.get()
                graph, traversedList = spread(word=totraverse['term'], graph=graph, traversedList=traversedList, previousScore=totraverse['weight'])

    else:
        return graph, traversedList
    
    return graph, traversedList

# %%
#%%pixie_debugger
g2 = graph
g2 = processSent("Vaca está bezerro sede", g2)
print(g2)
# Out:
# {'sede': [1, {'term': 'intestino', 'weight': 0.9}, {'term': 'imunidade', 'weight': 0.9}, {'term': 'equino', 'weight': 0.9}, {'term': 'desidratação', 'weight': 0.9}, {'term': 'ataque', 'weight': 0.9}, {'term': 'lagoa', 'weight': 0.9}, {'term': 'calor', 'weight': 0.9}, {'term': 'bebedouro', 'weight': 0.9}, {'term': 'estresse', 'weight': 0.9}, {'term': 'seca', 'weight': 0.9}, {'term': 'líquido', 'weight': 0.9}, {'term': 'antibiótico', 'weight': 0.9}, {'term': 'novilho', 'weight': 0.9}, {'term': 'dieta', 'weight': 0.9}, {'term': 'temperatura', 'weight': 0.9}, {'term': 'bovino', 'weight': 0.9}, {'term': 'seco', 'weight': 0.9}, {'term': 'ordenha', 'weight': 0.9}, {'term': 'planta', 'weight': 0.9}, {'term': 'doença', 'weight': 0.9}, {'term': 'rebanho', 'weight': 0.9}, {'term': 'água', 'weight': 0.9}, {'term': 'animais', 'weight': 0.9}, {'term': 'bezerro', 'weight': 0.9}, {'term': 'vaca', 'weight': 0.9}, {'term': 'animal', 'weight': 0}], 'máximo': [{0}, {'term': 'teor', 'weight': 0}, {'term': 'população', 'weight': 0}, {'term': 'medida', 'weight': 0}, {'term': 'proteína', 'weight': 0}, {'term': 'alimento', 'weight': 0}, {'term': 'água', 'weight': 0}, {'term': 'animais', 'weight': 0}, {'term': 'grande', 'weight': 0}], 'zebuínas': [{0}, {'term': 'puro', 'weight': 0}, {'term': 'genético', 'weight': 0}, {'term': 'mestiço', 'weight': 0}, {'term': 'guzerá', 'weight': 0}, {'term': 'cruzamento', 'weight': 0}, {'term': 'gir', 'weight': 0}, {'term': 'animal', 'weight': 0}, {'term': 'vaca', 'weight': 0}, {'term': 'raça', 'weight': 0}], 'bezerra': [{0}, {'term': 'volumoso', 'weight': 0}, {'term': 'ração', 'weight': 0}, {'term': 'mestiço', 'weight': 0}, {'term': 'holandês', 'weight': 0}, {'term': 'desaleitamento', 'weight': 0}, {'term': 'pastagem', 'weight': 0}, {'term': 'instalação', 'weight': 0}, {'term': 'imunoglobulina', 'weight': 0}, {'term': 'cuidado', 'weight': 0}, {'term': 'alimento', 'weight': 0}, {'term': 'teto', 'weight': 0}, {'term': 'pé', 'weight': 0}, {'term': 'proteína', 'weight': 0}, {'term': 'novilho', 'weight': 0}, {'term': 'mãe', 'weight': 0}, {'term': 'grande', 'weight': 0}, {'term': 'lactação', 'weight': 0}, {'term': 'desmamar', 'weight': 0}, {'term': 'raça', 'weight': 0}, {'term': 'animal', 'weight': 0}, {'term': 'abrigo', 'weight': 0}, {'term': 'doença', 'weight': 0}, {'term': 'mamar', 'weight': 0}, {'term': 'vaca', 'weight': 0}], 'decumbens': [{0}, {'term': 'brachiaria', 'weight': 0}], 'espécies': [{0}, {'term': 'vegetal', 'weight': 0}, {'term': 'superpastejo', 'weight': 0}, {'term': 'proteína', 'weight': 0}, {'term': 'plantio', 'weight': 0}, {'term': 'organismo', 'weight': 0}, {'term': 'doméstico', 'weight': 0}, {'term': 'cromossomo', 'weight': 0}, {'term': 'arbóreo', 'weight': 0}, {'term': 'panicum', 'weight': 0}, {'term': 'inseto', 'weight': 0}, {'term': 'cultura', 'weight': 0}, {'term': 'mosca', 'weight': 0}, {'term': 'leguminoso', 'weight': 0}, {'term': 'cigarra', 'weight': 0}, {'term': 'tropical', 'weight': 0}, {'term': 'braquiária', 'weight': 0}, {'term': 'brachiaria', 'weight': 0}, {'term': 'animais', 'weight': 0}, {'term': 'pastejo', 'weight': 0}, {'term': 'forrageiro', 'weight': 0}, {'term': 'gramínea', 'weight': 0}, {'term': 'planta', 'weight': 0}, {'term': 'forragem', 'weight': 0}, {'term': 'solo', 'weight': 0}, {'term': 'animal', 'weight': 0}], 'brizantha': [{0}, {'term': 'brachiaria', 'weight': 0}], 'concentração': [{0}, {'term': 'salinidade', 'weight': 0.5000000000000001}, {'term': 'magnésio', 'weight': 0.5000000000000001}, {'term': 'forrageira', 'weight': 0.5000000000000001}, {'term': 'silagem', 'weight': 0.5000000000000001}, {'term': 'forragem', 'weight': 0.5000000000000001}, {'term': 'alto', 'weight': 0.5000000000000001}, {'term': 'solo', 'weight': 0.5000000000000001}, {'term': 'proteína', 'weight': 0.5000000000000001}, {'term': 'nutriente', 'weight': 0.5000000000000001}, {'term': 'alimento', 'weight': 0.5000000000000001}, {'term': 'ração', 'weight': 0.5000000000000001}, {'term': 'mineral', 'weight': 0.500 ...
