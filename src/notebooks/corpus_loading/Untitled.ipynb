# %%
from nltk.corpus.reader import CategorizedPlaintextCorpusReader
import os
print(os.getcwd())
#os.chdir('..')
#print(os.getcwd())
# Out:
# C:\Users\Tiago Duque\textO\src\notebooks\corpus_loading

# %%
corpus = CategorizedPlaintextCorpusReader('../../../data/MilkPoint/2019-01-09/', r'.*\.txt', cat_pattern=r'(\w+)_([0-9]+)\.txt')

# %%
print(corpus.fileids())
# Out:
# ['criacaodeanimaisjovens_1103.txt', 'criacaodeanimaisjovens_1111.txt', 'criacaodeanimaisjovens_1198.txt', 'criacaodeanimaisjovens_1327.txt', 'criacaodeanimaisjovens_1328.txt', 'criacaodeanimaisjovens_1334.txt', 'criacaodeanimaisjovens_1389.txt', 'criacaodeanimaisjovens_1487.txt', 'criacaodeanimaisjovens_1488.txt', 'criacaodeanimaisjovens_1493.txt', 'criacaodeanimaisjovens_1516.txt', 'criacaodeanimaisjovens_1527.txt', 'criacaodeanimaisjovens_1551.txt', 'criacaodeanimaisjovens_1555.txt', 'criacaodeanimaisjovens_1618.txt', 'criacaodeanimaisjovens_1627.txt', 'criacaodeanimaisjovens_1674.txt', 'criacaodeanimaisjovens_1675.txt', 'criacaodeanimaisjovens_1742.txt', 'criacaodeanimaisjovens_1766.txt', 'criacaodeanimaisjovens_1828.txt', 'criacaodeanimaisjovens_1903.txt', 'criacaodeanimaisjovens_1907.txt', 'criacaodeanimaisjovens_1912.txt', 'criacaodeanimaisjovens_2003.txt', 'criacaodeanimaisjovens_2017.txt', 'criacaodeanimaisjovens_2019.txt', 'criacaodeanimaisjovens_2020.txt', 'criacaodeanimais
# ...
